# %% [markdown]
# # Download concept and random datasets

# %%
from datasets import load_dataset, load_from_disk

# %%
# Import dataset from HuggingFace
tweet_emotion = load_dataset('tweet_eval', 'emotion')
# Out:
# ...
# Generating validation split:   0%|          | 0/374 [00:00<?, ? examples/s]
# Dataset tweet_eval downloaded and prepared to /zhome/a6/6/127219/.cache/huggingface/datasets/tweet_eval/emotion/1.1.0/12aee5282b8784f3e95459466db4cdf45c6bf49719c25cdb0743d71ed0410343. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
train_emotion = tweet_emotion["train"]
validation_emotion = tweet_emotion["validation"]
test_emotion = tweet_emotion["test"]

# %%
# save datasets
train_emotion.save_to_disk('/work3/s174498/concept_random_dataset/tweet_emotion/train')
validation_emotion.save_to_disk('/work3/s174498/concept_random_dataset/tweet_emotion/validation')
test_emotion.save_to_disk('/work3/s174498/concept_random_dataset/tweet_emotion/test')

# %%
ag_news = load_from_disk('/work3/s174498/concept_random_dataset/tweet_stance_atheism/train')

# %%
ag_news['text']
# Out:
# ['@user Bless Almighty God, Almighty Holy Spirit and the Messiah. #SemST',
#  'Take away hatred from some people, and you have men without faith. ~Eric Hoffer #SemST',
#  'I took my troubles to the Lord: I cried out to him, and he answered my prayer. Psalm 120:1 #signposts #powerofprayer #SemST',
#  "You can't think by yourself about life and believe in god. It just doesn't add up #SemST",
#  'RT @user Humanist love to everyone at #100AEUAssembly celebrating @user 100th Anniversary! Amazing! #ethicalcu... #SemST',
#  'This is #America, so no you cannot make laws based on your #religion. #SemST',
#  'God is so good! All the praises go up to Him! #SemST',
#  "You'd think, after 2,000 years, I would have found at least one person I'd want to tell some things to. But nope.   ~#God   #SemST",
#  "Daily time in God's Word yields lasting freedom. #assurance #SemST",
#  'RT "...That kind of modesty is too arrogant for me."Christopher Hitchens 2/2" #Funny #SemST',
# ...

# %%
train_agnews = ag_news["train"]
test_agnews = ag_news["test"]

# %%
# save datasets
train_agnews.save_to_disk('/work3/s174498/concept_random_dataset/ag_news/train')
test_agnews.save_to_disk('/work3/s174498/concept_random_dataset/ag_news/test')
